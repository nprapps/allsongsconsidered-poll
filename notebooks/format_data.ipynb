# %%
# -*- coding: utf-8 -*-
# %matplotlib inline

import pandas as pd
import numpy as np
import math
import matplotlib as mplstyle
import matplotlib.pyplot as plt
import locale
import arrow
from locale import atof
from dateutil import parser
from datetime import datetime

# %% [markdown]
# ### TODOS
# - transform data to 6 columns ['id','day','timestamp','artist','album','points']

# %%
# Import unaltered test data
df = pd.read_csv("data/Vote For 2016's Best Albums (Responses) - Form Responses 1.csv")

# Import test data (artist and album separate should resemble 2017)
albums = pd.read_csv('data/test_data.csv')

# Drop empty columns
albums = albums.drop(['Unnamed: 11', 'Unnamed: 12'], axis=1)

# %%
# Keep only the rows with at least 2 non-na values
albums_cleaned = albums.dropna(thresh=2)

# Convert timestamp to datetime 
albums_cleaned['Timestamp'] = pd.to_datetime(albums_cleaned['Timestamp'])
albums_cleaned
# .sort_values('Timestamp')
# Out:
# /Users/bmayes/.virtualenvs/allsongsconsidered-poll/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
#                Timestamp                                   Artist Rank 1  \
# 0    2016-12-05 07:31:50                                         Beyonce
# 1    2016-12-05 07:34:17                                       Radiohead
# 2    2016-12-05 07:53:03                                         Solange
# 3    2016-12-05 07:54:56                                            Ry X
# 4    2016-12-05 12:32:36                                         solange
# 5    2016-12-05 12:34:05                               Chance the Rapper
# 6    2016-12-05 12:35:24                                     Angel Olsen
# ...
